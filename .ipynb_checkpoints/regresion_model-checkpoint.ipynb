# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn import linear_model, metrics
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv("dataset.csv", low_memory=False)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 68965 entries, 0 to 68964
# Data columns (total 25 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   marka_pojazdu            68964 non-null  object
#  1   rok_produkcji            68749 non-null  float64
#  2   moc                      68702 non-null  float64
#  3   model_pojazdu            68964 non-null  object
#  4   skrzynia_biegow          47753 non-null  object
#  5   wersja                   43602 non-null  object
#  6   kraj_pochodzenia         68965 non-null  object
#  7   uszkodzony               3013 non-null   object
#  8   zarejestrowany_w_polsce  37980 non-null  object
#  9   generacja                46283 non-null  object
#  10  stan                     68749 non-null  object
#  11  rodzaj_lakieru           51057 non-null  object
#  12  bezwypadkowy             43380 non-null  object
#  13  rodzaj_paliwa            68729 non-null  object
#  14  l_miejsc                 65689 non-null  float64
#  15  pojemnosc_skokowa        47247 non-null  float64
#  16  przebieg                 68246 non-null  float64
#  17  czy_zabytek              58 non-null     object
#  18  kolor                    65418 non-null  object
#  19  srednie_spalanie         68965 non-null  float64
#  20  typ_nadwozia             68749 non-null  object
#  21  cena                     68749 non-null  float64
#  22  l_drzwi                  68420 non-null  float64
#  23  naped                    41523 non-null  object
#  24  link                     68749 non-null  object
# dtypes: float64(8), object(17)
# memory usage: 13.2+ MB

# %%
df.corr()
# Out:
#                    rok_produkcji       moc  l_miejsc  pojemnosc_skokowa  \
# rok_produkcji           1.000000  0.217005  0.041601          -0.110400
# moc                     0.217005  1.000000 -0.047654           0.810162
# l_miejsc                0.041601 -0.047654  1.000000          -0.004875
# pojemnosc_skokowa      -0.110400  0.810162 -0.004875           1.000000
# przebieg               -0.659066 -0.187372  0.090918           0.089379
# srednie_spalanie        0.019839  0.032695  0.009031           0.027886
# cena                    0.051188  0.083581 -0.010417           0.042035
# l_drzwi                 0.222289 -0.175281  0.316155          -0.232292
#
#                    przebieg  srednie_spalanie      cena   l_drzwi
# rok_produkcji     -0.659066          0.019839  0.051188  0.222289
# moc               -0.187372          0.032695  0.083581 -0.175281
# l_miejsc           0.090918          0.009031 -0.010417  0.316155
# pojemnosc_skokowa  0.089379          0.027886  0.042035 -0.232292
# przebieg           1.000000         -0.025668 -0.052376 -0.021068
# srednie_spalanie  -0.025668          1.000000  0.002430  0.002616
# cena              -0.052376          0.002430  1.000000 -0.007960
# l_drzwi           -0.021068          0.002616 -0.007960  1.000000

# %%
df["cena"] = df["cena"].fillna(-1)
# df["cena"] = df["cena"].astype("int")

# %%
average_cars = df[df["cena"].between(100, 200000)]
average_cars.head(6)
# Out:
#   marka_pojazdu  rok_produkcji    moc    model_pojazdu skrzynia_biegow  \
# 0    Volkswagen         2017.0  150.0           Tiguan    Automatyczna
# 1           BMW         2018.0  140.0               X1    Automatyczna
# 2         Dacia         2022.0  100.0  Sandero Stepway        Manualna
# 3          Ford         2018.0   86.0            Focus        Manualna
# 4        Toyota         2020.0  132.0          Corolla        Manualna
# 5           Kia         2006.0   65.0          Picanto        Manualna
#
#                             wersja kraj_pochodzenia uszkodzony  \
# 0  2.0 TDI BMT SCR Comfortline DSG           Polska        NaN
# 1                        sDrive18i           Polska        NaN
# 2                              NaN             Inny        NaN
# 3                        1.6 Trend             Inny        NaN
# 4                              NaN           Polska        NaN
# 5                       1.1 (els4)           Niemcy        NaN
#
#   zarejestrowany_w_polsce          generacja  ... pojemnosc_skokowa  przebieg  \
# 0                     Tak         II (2016-)  ...            1968.0  133000.0
# 1                     Tak    F48 (2015-2022)  ...            1499.0   73216.0
# 2                     NaN                NaN  ...             999.0      10.0
# 3                     NaN    Mk3 (2010-2018)  ...            1596.0  192763.0
# 4                     Tak  Seria E21 (2019-)  ...            1598.0   40572.0
# 5                     NaN      I (2004-2010)  ...            1086.0  150240.0
#
#   czy_zabytek      kolor  srednie_spalanie   typ_nadwozia      cena l_drzwi  \
# 0         NaN     czarny               0.0            SUV  103900.0     5.0
# 1         NaN     czarny               0.0            SUV  112900.0     5.0
# 2         NaN      złoty               0.0  Auta miejskie   77400.0     5.0
# 3         NaN        NaN               0.0          Sedan   26500.0     4.0
# 4         NaN  niebieski               0.0          Sedan   79900.0     4.0
# 5         NaN     czarny               0.0      Auta małe    8999.0     5.0
#
#               naped                                               link
# 0  Na przednie koła  https://www.otomoto.pl/oferta/volkswagen-tigua...
# 1  Na przednie koła  https://www.otomoto.pl/oferta/bmw-x1-sdrive18i...
# 2  Na przednie koła  https://www.otomoto.pl/oferta/dacia-sandero-st...
# 3               NaN  https://www.otomoto.pl/oferta/ford-focus-ford-...
# 4  Na przednie koła  https://www.otomoto.pl/oferta/toyota-corolla-1...
# 5  Na przednie koła  https://www.otomoto.pl/oferta/kia-picanto-1-1p...
#
# [6 rows x 25 columns]

# %%
average_cars.describe()
# Out:
#        rok_produkcji           moc      l_miejsc  pojemnosc_skokowa  \
# count   61456.000000  61429.000000  58686.000000       42638.000000
# mean     2013.489798    150.438441      5.039618        1839.106361
# std         6.348847     63.587041      0.690209         674.846905
# min      1935.000000      1.000000      1.000000         400.000000
# 25%      2010.000000    110.000000      5.000000        1469.000000
# 50%      2015.000000    140.000000      5.000000        1796.000000
# 75%      2018.000000    177.000000      5.000000        1995.000000
# max      2023.000000    707.000000      9.000000        8200.000000
#
#            przebieg  srednie_spalanie           cena       l_drzwi
# count  6.124600e+04      61456.000000   61456.000000  61197.000000
# mean   1.430966e+05          0.170314   64157.572792      4.709022
# std    9.225024e+04          1.076652   48112.634390      0.675909
# min    1.000000e+00          0.000000    1400.000000      2.000000
# 25%    7.141300e+04          0.000000   25900.000000      5.000000
# 50%    1.450000e+05          0.000000   49900.000000      5.000000
# 75%    2.038000e+05          0.000000   89900.000000      5.000000
# max    1.830000e+06         19.000000  200000.000000      5.000000

# %%
cols = ["rok_produkcji", "moc", "pojemnosc_skokowa", "przebieg", "srednie_spalanie", "cena"]


fig, axes = plt.subplots(3, 2, figsize=(15, 15))
axes = axes.ravel()  


for col, ax in zip(cols, axes):
    sns.histplot(data=average_cars[col], kde=True, stat='density', ax=ax)

fig.tight_layout()
plt.show()

# sns.displot(average_cars["cena"])

# %%
sns.heatmap(average_cars.corr(), annot=True, cmap="Blues")
# Out:
# <AxesSubplot:>

# %%
average_cars.shape
# Out:
# (61456, 25)

# %%
average_cars[["cena", "rok_produkcji", "moc", "przebieg"]].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 61456 entries, 0 to 68964
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   cena           61456 non-null  float64
#  1   rok_produkcji  61456 non-null  float64
#  2   moc            61429 non-null  float64
#  3   przebieg       61246 non-null  float64
# dtypes: float64(4)
# memory usage: 2.3 MB

# %%
average_cars = average_cars.dropna(subset=["moc", "rok_produkcji", "przebieg"])

# %%
X  = average_cars[["moc", "rok_produkcji", "przebieg"]]
y = average_cars["cena"]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4)

reg = linear_model.LinearRegression()
reg.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
print('Coefficients: ', reg.coef_)
print('Variance score: {}'.format(reg.score(X_test, y_test)))
# Out:
# Coefficients:  [ 3.36532513e+02  2.89789657e+03 -1.85301251e-01]
# Variance score: 0.6629923281567651

# %%
## setting plot style
plt.style.use('fivethirtyeight')

## plotting residual errors in training data
plt.scatter(reg.predict(X_train), reg.predict(X_train) - y_train, color = "green", s = 10, label = 'Train data')

## plotting residual errors in test data
plt.scatter(reg.predict(X_test), reg.predict(X_test) - y_test, color = "blue", s = 10, label = 'Test data')

## plotting line for zero residual error
plt.hlines(y = 0, xmin = 0, xmax = 50, linewidth = 2)

## plotting legend
plt.legend(loc = 'upper right')

## plot title
plt.title("Residual errors")

## method call for showing the plot
plt.show()
